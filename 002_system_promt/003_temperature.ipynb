# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (0.86.0)
# Requirement already satisfied: python-dotenv in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.17.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (2.12.5)
# Requirement already satisfied: sniffio in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\manuel pastrana\appdata\roaming\python\python313\site-packages (from anyio<5,>=3.5.0->anthropic) (3.10)
# Requirement already satisfied: certifi in c:\users\manuel pastrana\appdata\roaming\python\python313\site-packages (from httpx<1,>=0.25.0->anthropic) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\manuel pastrana\appdata\local\programs\python\python313\lib\site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load Variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client
from anthropic import Anthropic
import os

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Funciones auxiliares
from os import system


def add_user_message(messages, user_input):
    messages.append({"role": "user", "content": user_input})

def add_assistant_message(messages, answer):
    messages.append({"role": "assistant", "content": answer})

def chat(messages, system=None, temperature=1.0):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

# %%
# Lista de mensajes para mantener un historial de la conversación
messages = []

user_input = input("> ")
print(">", user_input)

add_user_message(messages, user_input)
answer = chat(messages,temperature=0.7)
add_assistant_message(messages, answer)

print("---")
print(answer)
# Out:
# > generate a one sentence movie idea
# ---
# A retired astronaut discovers her memories of a Mars mission that never officially happened are actually real, forcing her to uncover why the government erased humanity's first contact with alien life.
