# %%
# Install dependencies
# %pip install anthropic python-dotenv
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Load Variables
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# Create an API Client
from anthropic import Anthropic
import os

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Funciones auxiliares
from os import system

def add_user_message(messages, user_input):
    messages.append({"role": "user", "content": user_input})

def add_assistant_message(messages, answer):
    messages.append({"role": "assistant", "content": answer})

def chat(messages, system=None, temperature=1.0, stop_sequences=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature
    }
    if system:
        params["system"] = system
    if stop_sequences:
        params["stop_sequences"] = stop_sequences

    response = client.messages.create(**params)
    return response.content[0].text

# %%
# El código original del ejercicio  muestra que se requiere que muestre tres comandos de AWS CLI diferentes, 
# cada uno debe ser muy corto. 

from IPython.display import Markdown
# Lista de mensajes para mantener un historial de la conversación
messages = []

prompt = """
Generate three differente sample AWS CLI commands. Each should be a very short
"""
#se hace el llamado a la funcion para agregar el mensaje del usuario a la lista de mensajes
add_user_message(messages, prompt)
add_assistant_message(messages, "here are all three commands in a single block without any comments:\n```bash")

text= chat(messages, temperature=0.7, stop_sequences=["```"])
text.strip()
# Out:
# 'aws s3 ls\n\naws ec2 describe-instances --region us-east-1\n\naws lambda list-functions --max-items 10'
