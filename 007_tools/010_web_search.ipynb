# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
web_search_schema = {
    "type": "web_search_20250305",
    "name": "web_search",
    "max_uses": 5,
    "allowed_domains": ["nih.gov"],
}

# %%
messages = []
add_user_message(
    messages,
    """
    What's the best exercise for gaining leg muscle?
    """,
)
response = chat(messages, tools=[web_search_schema])
response
# Out:
# Message(id='msg_01Y1sYnSAyxKAVVRLeWGfMNV', container=None, content=[TextBlock(citations=None, text='There isn\'t a single "best" exercise for gaining leg muscle, but **squats** are widely considered one of the most effective compound movements for overall leg development. Here\'s why and what else to consider:\n\n## Top Exercises for Leg Muscle Growth\n\n**Squats (Back Squats)**\n- Target all major leg muscles: quadriceps, hamstrings, glutes, and calves\n- Allow for progressive overload with heavy weights\n- Engage core and stabilizer muscles\n- Variations include front squats, goblet squats, and box squats\n\n**Other Highly Effective Exercises:**\n\n1. **Deadlifts** (especially Romanian deadlifts) - excellent for hamstrings and glutes\n2. **Lunges** - great for unilateral strength and balance\n3. **Leg Press** - allows heavy loading with less spinal stress\n4. **Bulgarian Split Squats** - intense single-leg work for quads and glutes\n5. **Leg Curls** - isolate hamstrings\n6. **Leg Extensions** - isolate quadriceps\n\n## Key Principles for Leg Muscle Growth\n\n- **Progressive Overload**: Gradually increase weight, reps, or volume over time\n- **Variety**: Combine compound movements (squats, deadlifts) with isolation exercises\n- **Frequency**: Train legs 2-3 times per week with adequate recovery\n- **Rep Ranges**: Use 6-12 reps for hypertrophy (muscle growth)\n- **Nutrition**: Ensure adequate protein intake and caloric surplus\n\nThe "best" exercise ultimately depends on your individual goals, experience level, available equipment, and any physical limitations. Most effective leg programs include a combination of these exercises rather than relying on just one.', type='text')], model='claude-sonnet-4-5-20250929', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=2228, output_tokens=400, server_tool_use=None, service_tier='standard'), stop_details=None)
