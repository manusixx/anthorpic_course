# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-sonnet-4-5"

# %%
# Helper functions
from anthropic.types import Message


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[], tools=None):
    params = {
        "model": model,
        "max_tokens": 4096,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Implementation of the TextEditorTool
import os
import shutil
from typing import Optional, List


class TextEditorTool:
    def __init__(self, base_dir: str = "", backup_dir: str = ""):
        self.base_dir = base_dir or os.getcwd()
        self.backup_dir = backup_dir or os.path.join(self.base_dir, ".backups")
        os.makedirs(self.backup_dir, exist_ok=True)

    def _validate_path(self, file_path: str) -> str:
        abs_path = os.path.normpath(os.path.join(self.base_dir, file_path))
        if not abs_path.startswith(self.base_dir):
            raise ValueError(
                f"Access denied: Path '{file_path}' is outside the allowed directory"
            )
        return abs_path

    def _backup_file(self, file_path: str) -> str:
        if not os.path.exists(file_path):
            return ""
        file_name = os.path.basename(file_path)
        backup_path = os.path.join(
            self.backup_dir, f"{file_name}.{os.path.getmtime(file_path):.0f}"
        )
        shutil.copy2(file_path, backup_path)
        return backup_path

    def _restore_backup(self, file_path: str) -> str:
        file_name = os.path.basename(file_path)
        backups = [
            f for f in os.listdir(self.backup_dir) if f.startswith(file_name + ".")
        ]
        if not backups:
            raise FileNotFoundError(f"No backups found for {file_path}")

        latest_backup = sorted(backups, reverse=True)[0]
        backup_path = os.path.join(self.backup_dir, latest_backup)

        shutil.copy2(backup_path, file_path)
        return f"Successfully restored {file_path} from backup"

    def _count_matches(self, content: str, old_str: str) -> int:
        return content.count(old_str)

    def view(self, file_path: str, view_range: Optional[List[int]] = None) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if os.path.isdir(abs_path):
                try:
                    return "\n".join(os.listdir(abs_path))
                except PermissionError:
                    raise PermissionError(
                        "Permission denied. Cannot list directory contents."
                    )

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            if view_range:
                start, end = view_range
                lines = content.split("\n")

                if end == -1:
                    end = len(lines)

                selected_lines = lines[start - 1 : end]

                result = []
                for i, line in enumerate(selected_lines, start):
                    result.append(f"{i}: {line}")

                return "\n".join(result)
            else:
                lines = content.split("\n")
                result = []
                for i, line in enumerate(lines, 1):
                    result.append(f"{i}: {line}")

                return "\n".join(result)

        except UnicodeDecodeError:
            raise UnicodeDecodeError(
                "utf-8",
                b"",
                0,
                1,
                "File contains non-text content and cannot be displayed.",
            )
        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot access file.")
        except Exception as e:
            raise type(e)(str(e))

    def str_replace(self, file_path: str, old_str: str, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            with open(abs_path, "r", encoding="utf-8") as f:
                content = f.read()

            match_count = self._count_matches(content, old_str)

            if match_count == 0:
                raise ValueError(
                    "No match found for replacement. Please check your text and try again."
                )
            elif match_count > 1:
                raise ValueError(
                    f"Found {match_count} matches for replacement text. Please provide more context to make a unique match."
                )

            # Create backup before modifying
            self._backup_file(abs_path)

            # Perform the replacement
            new_content = content.replace(old_str, new_str)

            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(new_content)

            return "Successfully replaced text at exactly one location."

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def create(self, file_path: str, file_text: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            # Check if file already exists
            if os.path.exists(abs_path):
                raise FileExistsError(
                    "File already exists. Use str_replace to modify it."
                )

            # Create parent directories if they don't exist
            os.makedirs(os.path.dirname(abs_path), exist_ok=True)

            # Create the file
            with open(abs_path, "w", encoding="utf-8") as f:
                f.write(file_text)

            return f"Successfully created {file_path}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot create file.")
        except Exception as e:
            raise type(e)(str(e))

    def insert(self, file_path: str, insert_line: int, new_str: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            # Create backup before modifying
            self._backup_file(abs_path)

            with open(abs_path, "r", encoding="utf-8") as f:
                lines = f.readlines()

            # Handle line endings
            if lines and not lines[-1].endswith("\n"):
                new_str = "\n" + new_str

            # Insert at the beginning if insert_line is 0
            if insert_line == 0:
                lines.insert(0, new_str + "\n")
            # Insert after the specified line
            elif insert_line > 0 and insert_line <= len(lines):
                lines.insert(insert_line, new_str + "\n")
            else:
                raise IndexError(
                    f"Line number {insert_line} is out of range. File has {len(lines)} lines."
                )

            with open(abs_path, "w", encoding="utf-8") as f:
                f.writelines(lines)

            return f"Successfully inserted text after line {insert_line}"

        except ValueError as e:
            raise ValueError(str(e))
        except PermissionError:
            raise PermissionError("Permission denied. Cannot modify file.")
        except Exception as e:
            raise type(e)(str(e))

    def undo_edit(self, file_path: str) -> str:
        try:
            abs_path = self._validate_path(file_path)

            if not os.path.exists(abs_path):
                raise FileNotFoundError("File not found")

            return self._restore_backup(abs_path)

        except ValueError as e:
            raise ValueError(str(e))
        except FileNotFoundError:
            raise FileNotFoundError("No previous edits to undo")
        except PermissionError:
            raise PermissionError("Permission denied. Cannot restore file.")
        except Exception as e:
            raise type(e)(str(e))

# %%
# Process Tool Call Requests
import json

text_editor_tool = TextEditorTool()


def run_tool(tool_name, tool_input):
    if tool_name == "str_replace_based_edit_tool":
        command = tool_input["command"]
        if command == "view":
            return text_editor_tool.view(
                tool_input["path"], tool_input.get("view_range")
            )
        elif command == "str_replace":
            return text_editor_tool.str_replace(
                tool_input["path"], tool_input["old_str"], tool_input["new_str"]
            )
        elif command == "create":
            if "file_text" not in tool_input:
                raise Exception("Missing required parameter 'file_text' for create command")
            return text_editor_tool.create(tool_input["path"], tool_input["file_text"])
        elif command == "insert":
            return text_editor_tool.insert(
                tool_input["path"],
                tool_input["insert_line"],
                tool_input["new_str"],
            )
        elif command == "undo_edit":
            return text_editor_tool.undo_edit(tool_input["path"])
        else:
            raise Exception(f"Unknown text editor command: {command}")
    else:
        raise Exception(f"Unknown tool name: {tool_name}")


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Make the text edit schema based on the model version being used
def get_text_edit_schema(model):
    if model.startswith("claude-3-7-sonnet"):
        return {
            "type": "text_editor_20250728",
            "name": "str_replace_based_edit_tool",
        }
    elif model.startswith("claude-sonnet-4-5"): 
        return {
            "type": "text_editor_20250728",
            "name": "str_replace_based_edit_tool",
        }
    else:
        raise Exception(f"Model {model} is not supported for the text editor tool")

# %%
# Run the conversation in a loop until the model doesn't ask for a tool use
def run_conversation(messages):
    while True:
        response = chat(
            messages,
            tools=[get_text_edit_schema(model)],
        )

        add_assistant_message(messages, response)
        print(text_from_message(response))

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

    return messages

# %% [markdown]
# # Lectura de archivo
# se le puede entregar a una función una ruta dada y darle a Claude una instrucciónn sobre uno o varios archivos.
# En este caso vamos a leer un archivo llamado main.py que se encuentra en la misma carpeta y le pediremos a Claude que nos lo explique

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and summarize its contents
    """,
)

run_conversation(messages)
# Out:
# I'll open and view the main.py file for you.
# ## Summary of main.py
#
# The file is very simple and contains:
#
# - **A single function** called `greeting()`
# - **Functionality**: When called, it prints the string `"hi there"` to the console
# - The file is only 2 lines long and contains minimal code - just a basic greeting function definition
#
# This appears to be a simple Python script, possibly a starting template or example file. The function itself is not currently being called anywhere in this file, so running the script as-is would not produce any output.
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and summarize its contents\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll open and view the main.py file for you.", type='text'),
#    ToolUseBlock(id='toolu_01XuxeYTcaCnp2wJRDDG6eMZ', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01XuxeYTcaCnp2wJRDDG6eMZ',
#     'content': '"1: def greeting():\\n2:     print (\\"hi there\\")"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='## Summary of main.py\n\nThe file is very simple and contains:\n\n- **A single function** called `greeting()`\n- **Functionality**: When called, it prints the string `"hi there"` to the console\n- The file is only 2 lines long and contains minimal code - just a basic greeting function definition\n\nThis appears to be a simple Python script, possibly a starting template or example file. The function itself is not currently being called anywhere in this file, so running the script as-is would not produce any output.', type='text')]}]

# %% [markdown]
# # Creación y modificación de archivos
#
# Aquí vamos a tomar el archivo main.py y modificarlo pidiendole a Claude que escriba una función para calcular el 5 número pi. Y luego le pediremos que cree una prueba para el archivo.
#
# # Nota:
# Tener cuidado que el número de tokens no sea muy pequeño. En este caso lo cambie de 1000 a 4096

# %%
messages = []

add_user_message(
    messages,
    """
    Open the ./main.py file and write out a function to calculate pi to 5th digit.
    Then create a ./test.py file with tests for that function. 
    Make sure to include all file contents when creating test.py.
    """,
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit in main.py and then create comprehensive tests in test.py.
#
# Let me start by viewing the current main.py file:
# Good! The main.py file already has functions to calculate pi. Now let me create a comprehensive test.py file with tests for these functions:
# Perfect! I've successfully created both files. Let me verify the test.py file was created correctly:
# Perfect! I've successfully completed both tasks:
#
# ## Summary
#
# ### **main.py**
# The file already contains a function `calculate_pi(digits=5)` that:
# - Calculates pi to the 5th decimal digit (3.14159) by default
# - Uses Machin's formula: `pi/4 = 4*arctan(1/5) - arctan(1/239)` for fast convergence
# - Accepts a parameter to specify the number of decimal digits
# - Also includes an alternative `calculate_pi_leibniz()` function for comparison
#
# ### **test.py** (Newly Created)
# Created comprehensive tests including:
#
# 1. **Accuracy tests:**
#    - Test default 5-digit calculation (3.14159)
#    - Test accuracy to 5 decimal places against math.pi
#    - Test various precision levels (0-5 digits)
#
# 2. **Type and range tests:**
#    - Verify correct return type (numeric)
#    - Verify pi is positive
#    - Verify pi is in the correct range (3 < pi < 4)
#
# 3. **Leibniz formula tests:**
#    - Test accuracy of the alternative method
#    - Test convergence improvement with more iterations
#    - Compare both methods to ensure consistency
#
# 4. **15 total test cases** covering edge cases and validating both calculation methods
#
# You can run the tests with: `python test.py` or `python -m unittest test.py`
# [{'role': 'user',
#   'content': '\n    Open the ./main.py file and write out a function to calculate pi to 5th digit.\n    Then create a ./test.py file with tests for that function. \n    Make sure to include all file contents when creating test.py.\n    '},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit in main.py and then create comprehensive tests in test.py.\n\nLet me start by viewing the current main.py file:", type='text'),
#    ToolUseBlock(id='toolu_01LxT7mV9pxH2XYXjKo69CRh', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './main.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01LxT7mV9pxH2XYXjKo69CRh',
#     'content': '"1: def greeting():\\n2:     print (\\"hi there\\")\\n3: \\n4: \\n5: def calculate_pi(digits=5):\\n6:     \\"\\"\\"\\n7:     Calculate pi to the specified number of decimal digits using the Machin formula.\\n8:     \\n9:     Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n10:     \\n11:     Args:\\n12:         digits: Number of decimal digits to calculate (default: 5)\\n13:     \\n14:     Returns:\\n15:         float: Approximation of pi\\n16:     \\"\\"\\"\\n17:     def arctan(x, num_terms):\\n18:         \\"\\"\\"Calculate arctan using Taylor series expansion.\\"\\"\\"\\n19:         result = 0\\n20:         x_squared = x * x\\n21:         x_power = x\\n22:         \\n23:         for n in range(num_terms):\\n24:             sign = (-1) ** n\\n25:             result += sign * x_power / (2 * n + 1)\\n26:             x_power *= x_squared\\n27:         \\n28:         return result\\n29:     \\n30:     # Number of terms needed for accuracy (more terms = more precision)\\n31:     # For 5 decimal places, we need enough terms\\n32:     num_terms = 500\\n33:     \\n34:     # Machin\'s formula: pi/4 = 4*arctan(1/5) - arctan(1/239)\\n35:     pi_over_4 = 4 * arctan(1/5, num_terms) - arctan(1/239, num_terms)\\n36:     pi_estimate = 4 * pi_over_4\\n37:     \\n38:     # Round to the specified number of digits\\n39:     return round(pi_estimate, digits)\\n40: \\n41: \\n42: def calculate_pi_leibniz(iterations=1000000):\\n43:     \\"\\"\\"\\n44:     Calculate pi using the Leibniz formula (slower convergence).\\n45:     \\n46:     Leibniz formula: pi/4 = 1 - 1/3 + 1/5 - 1/7 + 1/9 - ...\\n47:     \\n48:     Args:\\n49:         iterations: Number of iterations (default: 1000000)\\n50:     \\n51:     Returns:\\n52:         float: Approximation of pi\\n53:     \\"\\"\\"\\n54:     pi_estimate = 0\\n55:     \\n56:     for i in range(iterations):\\n57:         sign = (-1) ** i\\n58:         pi_estimate += sign / (2 * i + 1)\\n59:     \\n60:     return 4 * pi_estimate"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text='Good! The main.py file already has functions to calculate pi. Now let me create a comprehensive test.py file with tests for these functions:', type='text'),
#    ToolUseBlock(id='toolu_011V9CzuX7AEwFzgRSa2Kjs5', caller=DirectCaller(type='direct'), input={'command': 'create', 'path': './test.py', 'file_text': 'import unittest\nimport math\nfrom main import calculate_pi, calculate_pi_leibniz\n\n\nclass TestPiCalculation(unittest.TestCase):\n    """Test suite for pi calculation functions."""\n    \n    def test_calculate_pi_default_5_digits(self):\n        """Test that calculate_pi with default parameter returns pi to 5 decimal places."""\n        result = calculate_pi()\n        expected = 3.14159\n        self.assertEqual(result, expected, \n                         f"Expected pi to 5 digits: {expected}, got: {result}")\n    \n    def test_calculate_pi_accuracy_5_digits(self):\n        """Test that calculate_pi(5) is accurate to 5 decimal places."""\n        result = calculate_pi(5)\n        actual_pi = math.pi\n        # The result should be within 0.000005 of the actual value\n        self.assertAlmostEqual(result, actual_pi, places=5,\n                              msg=f"Pi calculation not accurate to 5 digits")\n    \n    def test_calculate_pi_3_digits(self):\n        """Test calculate_pi with 3 decimal places."""\n        result = calculate_pi(3)\n        expected = 3.142\n        self.assertEqual(result, expected,\n                        f"Expected pi to 3 digits: {expected}, got: {result}")\n    \n    def test_calculate_pi_2_digits(self):\n        """Test calculate_pi with 2 decimal places."""\n        result = calculate_pi(2)\n        expected = 3.14\n        self.assertEqual(result, expected,\n                        f"Expected pi to 2 digits: {expected}, got: {result}")\n    \n    def test_calculate_pi_1_digit(self):\n        """Test calculate_pi with 1 decimal place."""\n        result = calculate_pi(1)\n        expected = 3.1\n        self.assertEqual(result, expected,\n                        f"Expected pi to 1 digit: {expected}, got: {result}")\n    \n    def test_calculate_pi_0_digits(self):\n        """Test calculate_pi with 0 decimal places (integer)."""\n        result = calculate_pi(0)\n        expected = 3.0\n        self.assertEqual(result, expected,\n                        f"Expected pi to 0 digits: {expected}, got: {result}")\n    \n    def test_calculate_pi_return_type(self):\n        """Test that calculate_pi returns a numeric type."""\n        result = calculate_pi(5)\n        self.assertIsInstance(result, (int, float),\n                            "calculate_pi should return a numeric value")\n    \n    def test_calculate_pi_positive(self):\n        """Test that calculate_pi returns a positive value."""\n        result = calculate_pi(5)\n        self.assertGreater(result, 0,\n                          "Pi should be positive")\n    \n    def test_calculate_pi_range(self):\n        """Test that calculate_pi returns a value in the expected range."""\n        result = calculate_pi(5)\n        self.assertGreater(result, 3.0,\n                          "Pi should be greater than 3")\n        self.assertLess(result, 4.0,\n                       "Pi should be less than 4")\n    \n    def test_calculate_pi_leibniz_accuracy(self):\n        """Test that calculate_pi_leibniz produces a reasonable approximation."""\n        result = calculate_pi_leibniz(1000000)\n        actual_pi = math.pi\n        # Leibniz converges slowly, so we check with less precision\n        self.assertAlmostEqual(result, actual_pi, places=5,\n                              msg="Leibniz formula should approximate pi")\n    \n    def test_calculate_pi_leibniz_return_type(self):\n        """Test that calculate_pi_leibniz returns a numeric type."""\n        result = calculate_pi_leibniz(1000)\n        self.assertIsInstance(result, (int, float),\n                            "calculate_pi_leibniz should return a numeric value")\n    \n    def test_calculate_pi_leibniz_positive(self):\n        """Test that calculate_pi_leibniz returns a positive value."""\n        result = calculate_pi_leibniz(1000) ...
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_011V9CzuX7AEwFzgRSa2Kjs5',
#     'content': '"Successfully created ./test.py"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully created both files. Let me verify the test.py file was created correctly:", type='text'),
#    ToolUseBlock(id='toolu_01JfXLqyyrqGQPdTSPGiS2q1', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': './test.py'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01JfXLqyyrqGQPdTSPGiS2q1',
#     'content': '"1: import unittest\\n2: import math\\n3: from main import calculate_pi, calculate_pi_leibniz\\n4: \\n5: \\n6: class TestPiCalculation(unittest.TestCase):\\n7:     \\"\\"\\"Test suite for pi calculation functions.\\"\\"\\"\\n8:     \\n9:     def test_calculate_pi_default_5_digits(self):\\n10:         \\"\\"\\"Test that calculate_pi with default parameter returns pi to 5 decimal places.\\"\\"\\"\\n11:         result = calculate_pi()\\n12:         expected = 3.14159\\n13:         self.assertEqual(result, expected, \\n14:                          f\\"Expected pi to 5 digits: {expected}, got: {result}\\")\\n15:     \\n16:     def test_calculate_pi_accuracy_5_digits(self):\\n17:         \\"\\"\\"Test that calculate_pi(5) is accurate to 5 decimal places.\\"\\"\\"\\n18:         result = calculate_pi(5)\\n19:         actual_pi = math.pi\\n20:         # The result should be within 0.000005 of the actual value\\n21:         self.assertAlmostEqual(result, actual_pi, places=5,\\n22:                               msg=f\\"Pi calculation not accurate to 5 digits\\")\\n23:     \\n24:     def test_calculate_pi_3_digits(self):\\n25:         \\"\\"\\"Test calculate_pi with 3 decimal places.\\"\\"\\"\\n26:         result = calculate_pi(3)\\n27:         expected = 3.142\\n28:         self.assertEqual(result, expected,\\n29:                         f\\"Expected pi to 3 digits: {expected}, got: {result}\\")\\n30:     \\n31:     def test_calculate_pi_2_digits(self):\\n32:         \\"\\"\\"Test calculate_pi with 2 decimal places.\\"\\"\\"\\n33:         result = calculate_pi(2)\\n34:         expected = 3.14\\n35:         self.assertEqual(result, expected,\\n36:                         f\\"Expected pi to 2 digits: {expected}, got: {result}\\")\\n37:     \\n38:     def test_calculate_pi_1_digit(self):\\n39:         \\"\\"\\"Test calculate_pi with 1 decimal place.\\"\\"\\"\\n40:         result = calculate_pi(1)\\n41:         expected = 3.1\\n42:         self.assertEqual(result, expected,\\n43:                         f\\"Expected pi to 1 digit: {expected}, got: {result}\\")\\n44:     \\n45:     def test_calculate_pi_0_digits(self):\\n46:         \\"\\"\\"Test calculate_pi with 0 decimal places (integer).\\"\\"\\"\\n47:         result = calculate_pi(0)\\n48:         expected = 3.0\\n49:         self.assertEqual(result, expected,\\n50:                         f\\"Expected pi to 0 digits: {expected}, got: {result}\\")\\n51:     \\n52:     def test_calculate_pi_return_type(self):\\n53:         \\"\\"\\"Test that calculate_pi returns a numeric type.\\"\\"\\"\\n54:         result = calculate_pi(5)\\n55:         self.assertIsInstance(result, (int, float),\\n56:                             \\"calculate_pi should return a numeric value\\")\\n57:     \\n58:     def test_calculate_pi_positive(self):\\n59:         \\"\\"\\"Test that calculate_pi returns a positive value.\\"\\"\\"\\n60:         result = calculate_pi(5)\\n61:         self.assertGreater(result, 0,\\n62:                           \\"Pi should be positive\\")\\n63:     \\n64:     def test_calculate_pi_range(self):\\n65:         \\"\\"\\"Test that calculate_pi returns a value in the expected range.\\"\\"\\"\\n66:         result = calculate_pi(5)\\n67:         self.assertGreater(result, 3.0,\\n68:                           \\"Pi should be greater than 3\\")\\n69:         self.assertLess(result, 4.0,\\n70:                        \\"Pi should be less than 4\\")\\n71:     \\n72:     def test_calculate_pi_leibniz_accuracy(self):\\n73:         \\"\\"\\"Test that calculate_pi_leibniz produces a reasonable approximation.\\"\\"\\"\\n74:         result = calculate_pi_leibniz(1000000)\\n75:         actual_pi = math.pi\\n76:         # Leibniz converges slowly, so we check with less precision\\n77:         self.assertAlmostEqual(result, actual_pi, places=5,\\n78:                               msg=\\"Leibniz formula should approximate pi\\")\\n79:     \\n80:     def test_calculate_pi_leibniz_return_type( ...
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="Perfect! I've successfully completed both tasks:\n\n## Summary\n\n### **main.py** \nThe file already contains a function `calculate_pi(digits=5)` that:\n- Calculates pi to the 5th decimal digit (3.14159) by default\n- Uses Machin's formula: `pi/4 = 4*arctan(1/5) - arctan(1/239)` for fast convergence\n- Accepts a parameter to specify the number of decimal digits\n- Also includes an alternative `calculate_pi_leibniz()` function for comparison\n\n### **test.py** (Newly Created)\nCreated comprehensive tests including:\n\n1. **Accuracy tests:**\n   - Test default 5-digit calculation (3.14159)\n   - Test accuracy to 5 decimal places against math.pi\n   - Test various precision levels (0-5 digits)\n\n2. **Type and range tests:**\n   - Verify correct return type (numeric)\n   - Verify pi is positive\n   - Verify pi is in the correct range (3 < pi < 4)\n\n3. **Leibniz formula tests:**\n   - Test accuracy of the alternative method\n   - Test convergence improvement with more iterations\n   - Compare both methods to ensure consistency\n\n4. **15 total test cases** covering edge cases and validating both calculation methods\n\nYou can run the tests with: `python test.py` or `python -m unittest test.py`", type='text')]}]
